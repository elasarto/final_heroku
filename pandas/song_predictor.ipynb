# %%
import spotipy
import spotipy.util as util
from config import CLIENT_ID, CLIENT_SECRET
import random
import pprint
import pandas as pd

# %%
token = util.oauth2.SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)

cache_token = token.get_access_token()
spotify = spotipy.Spotify(cache_token)

# %%
results = spotify.search(q='ABBA', limit=5)
pprint.pprint(results['tracks']['items'][4])
# Out:
# {'album': {'album_type': 'album',
#            'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LcJLqbBmaGUft1e9Mm8HV'},
#                         'href': 'https://api.spotify.com/v1/artists/0LcJLqbBmaGUft1e9Mm8HV',
#                         'id': '0LcJLqbBmaGUft1e9Mm8HV',
#                         'name': 'ABBA',
#                         'type': 'artist',
#                         'uri': 'spotify:artist:0LcJLqbBmaGUft1e9Mm8HV'}],
#            'available_markets': ['CA', 'MX', 'US'],
#            'external_urls': {'spotify': 'https://open.spotify.com/album/0zdZSyxWaYmaRMPeUHcG1K'},
#            'href': 'https://api.spotify.com/v1/albums/0zdZSyxWaYmaRMPeUHcG1K',
#            'id': '0zdZSyxWaYmaRMPeUHcG1K',
#            'images': [{'height': 575,
#                        'url': 'https://i.scdn.co/image/9a06fe3059762156cff0ea02053592bb625f9350',
#                        'width': 640},
#                       {'height': 270,
# ...

# %%
results4 = results['tracks']['items'][0]['artists'][0]['name']
results4
# Out:
# 'ABBA'

# %%
results2 = results['tracks']['items']

# %%
names = ["ABBA"]

for name in names:
    results = spotify.search(q="artist:" + name, limit=5)

    pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3AABBA&type=track&offset=0&limit=5',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LcJLqbBmaGUft1e9Mm8HV'},
#                                               'href': 'https://api.spotify.com/v1/artists/0LcJLqbBmaGUft1e9Mm8HV',
#                                               'id': '0LcJLqbBmaGUft1e9Mm8HV',
#                                               'name': 'ABBA',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:0LcJLqbBmaGUft1e9Mm8HV'}],
#                                  'available_markets': ['CA', 'MX', 'US'],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/1M4anG49aEs4YimBdj96Oy'},
# ...

# %%
track_ids = []
track_names = []
artist_names = []

names = ["ABBA", "Ace of Base", "Adam Sandler", "Adele", "Aerosmith"]

i = 0

for name in names:
    
    i = 0
    
    results = spotify.search(q=name, limit=5)
    other = results['tracks']['items']
    
    for result in other:
        
        track_ids.append(results['tracks']['items'][i]['id'])
        print(name, results['tracks']['items'][i]['name'])
        track_names.append(results['tracks']['items'][i]['name'])
        artist_names.append(name)

        i += 1
# Out:
# ABBA Dancing Queen
# ABBA Mamma Mia
# ABBA Take A Chance On Me
# ABBA Dancing Queen
# ABBA Gimme! Gimme! Gimme! (A Man After Midnight)
# Ace of Base The Sign
# Ace of Base All That She Wants
# Ace of Base All That She Wants
# Ace of Base Beautiful Life
# Ace of Base Don't Turn Around
# Adam Sandler Grow Old With You
# Adam Sandler Somebody Kill Me
# Adam Sandler At A Medium Pace
# Adam Sandler Chanukah Song - The
# Adam Sandler Ode To My Car
# Adele Someone Like You
# Adele Send My Love (To Your New Lover)
# Adele Rolling in the Deep
# Adele Hello
# Adele Set Fire to the Rain
# Aerosmith Dream On
# Aerosmith Sweet Emotion
# Aerosmith I Don't Want to Miss a Thing
# Aerosmith Walk This Way (feat. Aerosmith)
# Aerosmith Walk This Way

# %%
results = spotify.search(q='ABBA', limit=5)
len(results)
# Out:
# 1

# %%
results_df = pd.DataFrame({"Artist Name":artist_names, "Track Name":track_names, "Track ID":track_ids}, columns=["Artist Name", "Track Name", "Track ID"])
results_df
# Out:
#      Artist Name                                   Track Name  \
# 0           ABBA                                Dancing Queen
# 1           ABBA                                    Mamma Mia
# 2           ABBA                          Take A Chance On Me
# 3           ABBA                                Dancing Queen
# 4           ABBA  Gimme! Gimme! Gimme! (A Man After Midnight)
# 5    Ace of Base                                     The Sign
# 6    Ace of Base                           All That She Wants
# 7    Ace of Base                           All That She Wants
# 8    Ace of Base                               Beautiful Life
# 9    Ace of Base                            Don't Turn Around
# 10  Adam Sandler                            Grow Old With You
# 11  Adam Sandler                             Somebody Kill Me
# 12  Adam Sandler                             At A Medium Pace
# 13  Adam Sandler                          Chanukah Song - The
# ...

# %%
track_ids
# Out:
# ['4NtUY5IGzHCaqfZemmAu56',
#  '22NN4BS1AlqVbyKIWExgON',
#  '6vQN2a9QSgWcm74KEZYfDL',
#  '2ATDkfqprlNNe9mYWodgdc',
#  '2PzCOP5Aj9SABiBgNEZ52G']

# %%
features2 = spotify.audio_features(track_ids) 
df3 = pd.DataFrame(features2)
df3
# Out:
#     acousticness                                       analysis_url  \
# 0        0.42000  https://api.spotify.com/v1/audio-analysis/4NtU...
# 1        0.27300  https://api.spotify.com/v1/audio-analysis/22NN...
# 2        0.17300  https://api.spotify.com/v1/audio-analysis/6vQN...
# 3        0.19600  https://api.spotify.com/v1/audio-analysis/2ATD...
# 4        0.02250  https://api.spotify.com/v1/audio-analysis/2PzC...
# 5        0.00928  https://api.spotify.com/v1/audio-analysis/0hrB...
# 6        0.00526  https://api.spotify.com/v1/audio-analysis/12Bb...
# 7        0.00547  https://api.spotify.com/v1/audio-analysis/6kWJ...
# 8        0.20200  https://api.spotify.com/v1/audio-analysis/74jT...
# 9        0.00104  https://api.spotify.com/v1/audio-analysis/4SYM...
# 10       0.85800  https://api.spotify.com/v1/audio-analysis/2lVY...
# 11       0.71200  https://api.spotify.com/v1/audio-analysis/1LyW...
# 12       0.48600  https://api.spotify.com/v1/audio-analysis/5rjH...
# ...

# %%
track_ids = []

for result in results:

    track_ids.append(results['tracks']['items'][i]['id'])
# Out:
# '6vQN2a9QSgWcm74KEZYfDL'

# %%
results2 = results['tracks']['items']
pprint.pprint(results2)
# Out:
# [{'album': {'album_type': 'album',
#             'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LcJLqbBmaGUft1e9Mm8HV'},
#                          'href': 'https://api.spotify.com/v1/artists/0LcJLqbBmaGUft1e9Mm8HV',
#                          'id': '0LcJLqbBmaGUft1e9Mm8HV',
#                          'name': 'ABBA',
#                          'type': 'artist',
#                          'uri': 'spotify:artist:0LcJLqbBmaGUft1e9Mm8HV'}],
#             'available_markets': ['CA', 'MX', 'US'],
#             'external_urls': {'spotify': 'https://open.spotify.com/album/1M4anG49aEs4YimBdj96Oy'},
#             'href': 'https://api.spotify.com/v1/albums/1M4anG49aEs4YimBdj96Oy',
#             'id': '1M4anG49aEs4YimBdj96Oy',
#             'images': [{'height': 575,
#                         'url': 'https://i.scdn.co/image/de30d4da9efd1b491493ed288e09b6f935ff10ab',
#                         'width': 640},
#                        {'height': 270,
# ...

# %%
results3 = results2[0]['id']
pprint.pprint(results3)
# Out:
# '4NtUY5IGzHCaqfZemmAu56'

# %%
features = spotify.audio_features(results3) 
df = pd.DataFrame(features)
df
# Out:
#    acousticness                                       analysis_url  \
# 0          0.42  https://api.spotify.com/v1/audio-analysis/4NtU...
#
#    danceability  duration_ms  energy                      id  \
# 0         0.546       230693   0.879  4NtUY5IGzHCaqfZemmAu56
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0           0.00188    9     0.775    -6.397     1       0.0441  100.819
#
#    time_signature                                         track_href  \
# 0               4  https://api.spotify.com/v1/tracks/4NtUY5IGzHCa...
#
#              type                                   uri  valence
# 0  audio_features  spotify:track:4NtUY5IGzHCaqfZemmAu56    0.783
